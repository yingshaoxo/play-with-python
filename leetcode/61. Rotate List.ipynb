# %% [markdown]
# https://leetcode.com/problems/rotate-list/
#
#
# Runtime: 32 ms, faster than 91.94% of Python3 online submissions for Rotate List.
# Memory Usage: 14.4 MB, less than 28.15% of Python3 online submissions for Rotate List.
#
#
# ```python
# # Definition for singly-linked list.
# # class ListNode:
# #     def __init__(self, val=0, next=None):
# #         self.val = val
# #         self.next = next
# class Solution:
#     def rotateRight(self, head: ListNode, k: int) -> ListNode:
#         """
#         #7:15
#         l = []
#         node = head
#         while node != None:
#             l.append(node)
#             node = node.next
#
#         if len(l) == 0:
#             return None
#
#         index = k % len(l)
#         print(index)
#
#         new_l = l[index:] + l[:index]
#         for i, node in enumerate(new_l):
#             if i < len(new_l) - 1:
#                 node.next = new_l[i + 1]
#             else:
#                 node.next = None
#         return new_l[0]
#         #7:22
#         #wrong
#         """
#         # another day
#         # 8:44
#         l = []
#         node = head
#         while node != None:
#             l.append(node)
#             node = node.next
#
#         if len(l) == 0:
#             return None
#
#         k = k % len(l)
#         i = 0
#         while i < k:
#             l = l[-1:] + l[:-1]
#             i += 1
#
#         for i, node in enumerate(l):
#             if i < len(l) - 1:
#                 node.next = l[i + 1]
#             else:
#                 node.next = None
#         return l[0]
#         # 8:47
# ```
